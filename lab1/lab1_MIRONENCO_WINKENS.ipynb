# %% [markdown]
# # Lab 1: Independent Component Analysis
#
# ### Machine Learning 2 (2016/2017)
#
# * The lab exercises should be made in groups of two people.
# * The deadline is Wednesday, April 19, 23:59.
# * Assignment should be sent to p.j.j.p.versteeg@uva.nl. The subject line of your email should be "[ML2_2017] lab#_lastname1\_lastname2".
# * Put your and your teammates' names in the body of the email
# * Attach the .IPYNB (IPython Notebook) file containing your code and answers. Naming of the file follows the same rule as the subject line. For example, if the subject line is "[ML2_2016] lab01\_Bongers\_Blom", the attached file should be "lab01\_Bongers\_Blom.ipynb". Only use underscores ("\_") to connect names, otherwise the files cannot be parsed.
#
# Notes on implementation:
#
# * You should write your code and answers in an IPython Notebook: http://ipython.org/notebook.html. If you have problems, please ask.
# * Use __one cell__ for code and markdown answers only!
#     * Put all code in the cell with the `# YOUR CODE HERE' comment.
#     * For theoretical question, put your solution in the YOUR ANSWER HERE cell.
# * Among the first lines of your notebook should be "%pylab inline". This imports all required modules, and your plots will appear inline.
# * NOTE: test your code and make sure we can run your notebook / scripts!

# %% [markdown]
# ### Literature
# In this assignment, we will implement the Independent Component Analysis algorithm as described in chapter 34 of David MacKay's book "Information Theory, Inference, and Learning Algorithms", which is freely available here:
# http://www.inference.phy.cam.ac.uk/mackay/itila/book.html
#
# Read the ICA chapter carefuly before you continue!
#
# ### Notation
#
# $\mathbf{X}$ is the $M \times T$ data matrix, containing $M$ measurements at $T$ time steps.
#
# $\mathbf{S}$ is the $S \times T$ source matrix, containing $S$ source signal values at $T$ time steps. We will assume $S = M$.
#
# $\mathbf{A}$ is the mixing matrix. We have $\mathbf{X} = \mathbf{A S}$.
#
# $\mathbf{W}$ is the matrix we aim to learn. It is the inverse of $\mathbf{A}$, up to indeterminacies (scaling and permutation of sources).
#
# $\phi$ is an elementwise non-linearity or activation function, typically applied to elements of $\mathbf{W X}$.
#
# ### Code
# In the following assignments, you can make use of the signal generators listed below.

# %%
# %pylab inline

# Signal generators
def sawtooth(x, period=0.2, amp=1.0, phase=0.):
    return (((x / period - phase - 0.5) % 1) - 0.5) * 2 * amp

def sine_wave(x, period=0.2, amp=1.0, phase=0.):
    return np.sin((x / period - phase) * 2 * np.pi) * amp

def square_wave(x, period=0.2, amp=1.0, phase=0.):
    return ((np.floor(2 * x / period - 2 * phase - 1) % 2 == 0).astype(float) - 0.5) * 2 * amp

def triangle_wave(x, period=0.2, amp=1.0, phase=0.):
    return (sawtooth(x, period, 1., phase) * square_wave(x, period, 1., phase) + 0.5) * 2 * amp

def random_nonsingular_matrix(d=2):
    """
    Generates a random nonsingular (invertible) matrix of shape d*d
    """
    epsilon = 0.1
    A = np.random.rand(d, d)
    while abs(np.linalg.det(A)) < epsilon:
        A = np.random.rand(d, d)
    return A

def plot_signals(X, title=None):
    """
    Plot the signals contained in the rows of X.
    """
    fig = figure(figsize=(10,6))
    
    if title != None:
        fig.suptitle(title, fontsize=15)
    
    for i in range(X.shape[0]):
        ax = plt.subplot(X.shape[0], 1, i + 1)
        plot(X[i, :])
        ax.set_xticks([])
        ax.set_yticks([])
    plt.subplots_adjust(top=0.95)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# The following code generates some toy data to work with.

# %%
# Generate data
num_sources = 5
signal_length = 500
t = linspace(0, 1, signal_length)
S = np.c_[sawtooth(t), sine_wave(t, 0.3), square_wave(t, 0.4), triangle_wave(t, 0.25), np.random.randn(t.size)].T
plot_signals(S)

# %% [markdown]
# ### 1.1 Make mixtures (5 points)
# Write a function `make_mixtures(S, A)' that takes a matrix of source signals $\mathbf{S}$ and a mixing matrix $\mathbf{A}$, and generates mixed signals $\mathbf{X}$.

# %%
### 1.1 Make mixtures
def make_mixtures(S, A=None):
    if A is None:
        return S
    
    return np.dot(A,S)

A = random_nonsingular_matrix(d=S.shape[0])
X = make_mixtures(S, A)
plot_signals(X)

# %% [markdown]
# ### 1.2 Histogram (5 points)
# Write a function `plot_histograms(X)` that takes a data-matrix $\mathbf{X}$ and plots one histogram for each signal (row) in $\mathbf{X}$. You can use the numpy `histogram()` function.
#
# Plot histograms of the sources and the measurements.
# Which of these distributions (sources or measurements) tend to look more like Gaussians? Can you think of an explanation for this phenomenon? Why is this important for ICA?

# %%
### 1.2 Histogram
# YOUR CODE HERE
def plot_histograms(X, titles, title=None):
    if X is None or titles is None:
        raise TypeError('Cannot plot histogram of None')
    
    if len(X) != len(titles):
        raise ValueError('X rows and titles must correspond.')
    
    fig = figure(figsize=(18,4))
    
    if title != None:
        fig.suptitle(title, fontsize=15)
    
    for i, (source_row, title) in enumerate(zip(X, titles)):
        ax = plt.subplot(1, len(titles), i + 1)
        plt.title(title)
        plt.hist(source_row, bins='auto', edgecolor='k') # plt.hist passes it's arguments to np.histogram
    
    plt.tight_layout()
    plt.subplots_adjust(top=0.85)

plot_histograms(X, ['mix_1', 'mix_2', 'mix_3', 'mix_4', 'mix_5'], title='Mixture measurements')
plot_histograms(S, ['saw_tooth', 'sine_wave', 'square_wave', 'triangle_wave', 'random_wave'], title='Source signals')

# %% [markdown]
# - The essential assumptions of ICA are that the source signals are non-Gaussian and statistically independent. The first 4 source signals are non-Gaussian, however the 'random_wave' has a Gaussian shape as `numpy.random.randn` samples from the Gaussian distribution. This is problematic as the optimal conditions for ICA are no longer satisfied.
# - If the source is Gaussian, we will have an arbitrary rotational component in the data (X), that cannot be determined strictly from the mixture. This will stop us from recovering the source signal, and is motivated by the fact that the Gaussian density is rotationally symmetric (i.e. imagine x ~ N(0,I), datapoints of x will form contours around the origin).
#
# The mixture measurements all have a tendency to follow an approximately Gaussian shape. This can be explained by:
#
# 1.  The Central Limit Theorem, which states that the distirbution of a sum of independent random variables with finite covariance tends towards a Gaussian, i.e. the sum of source signals will follow the shape of a Gaussian, more than any individual source signal (except for the random wave).
# 2. A random variable that is distributed according to a Gaussian distribution as a component of the mixture.

# %% [markdown]
# ### 1.3 Implicit priors (20 points)
# As explained in MacKay's book, an activation function $\phi$ used in the ICA learning algorithm corresponds to a prior distribution over sources. Specifically, $\phi(a) = \frac{d}{da} \ln p(a)$. For each of the following activation functions, derive the source distribution they correspond to.
# $$\phi_0(a) = -\tanh(a)$$
# $$\phi_1(a) = -a + \tanh(a)$$
# $$\phi_2(a) = -a^3$$
# $$\phi_3(a) = -\frac{6a}{a^2 + 5}$$
#
# The normalizing constant is not required, so an answer of the form $p(a) \propto \verb+[answer]+$ is ok.
#
# Plot the activation functions and the corresponding prior distributions. Compare the shape of the priors to the histogram you plotted in the last question.

# %% [markdown]
# $$\phi_0(a) = -\tanh(a)$$
#
# $$\dfrac{d}{da}\ln p_1(a) = - \tanh(a)$$
#
# $$\ln p_0(a) = \int - \tanh(a) \textit{da}$$
#
# $$p_0(a) = \exp(- \int tanh(a) \textit{da})$$
#
# $$p_0(a) = \exp(- \int \dfrac{\sinh(a)}{\cosh(a)} \textit{da})$$
#
# $$u = \cosh(a); \textit{du} = \sinh(a)\textit{da}$$
#
# $$p_0(a) = \exp(-\int\dfrac{1}{u}\textit{du}) = \exp(-\ln|u|) = \exp(-\ln|\cosh(a)|)$$
#
# $$p_0(a) \propto \exp(\ln|\cosh(a)|^{-1}) \propto \dfrac{1}{\cosh(a)} \propto \dfrac{1}{e^{a} + e^{-a}}$$
#
# ---
#
# $$\phi_1(a) = -a + tanh(a)$$
#
# Using a similar derivation, we have:
#
# $$p_1(a) \propto \exp(- \dfrac{a^{2}}{2} + \ln|\cosh(a)|) \propto \exp(-\dfrac{a^{2}}{2}) \cdot \cosh(a)$$
#
# ---
#
# $$\phi_2(a) = -a^{3}$$
#
# $$p_2(a) \propto - \int a^{3}\textit{da}\propto\exp(-\dfrac{a^{4}}{4})$$
#
# ---
#
# $$\phi_3(a) = - \dfrac{6a}{a^{2} + 5}$$
#
# $$p_3(a) = \exp(\int - \dfrac{6a}{a^{2} + 5} \textit{da}) = \exp(-3 \ln|a^{2} + 5|)$$
#
# $$p_3(a) \propto (a^{2} + 5)^{-3}$$
#
# ---
#
# We therefore have:
#
# $$p_0(a) \propto \dfrac{1}{\cosh(a)} \propto \dfrac{1}{e^{a} + e^{-a}}$$
# $$p_1(a) \propto \exp(-\dfrac{a^{2}}{2}) \cdot \cosh(a)$$
# $$p_2(a) \propto\exp(-\dfrac{a^{4}}{4})$$
# $$p_3(a) \propto (a^{2} + 5)^{-3}$$
#
# ---
#
#
# **Comparison of shape of priors and activation functions (see next cell for results)**
#
# The priors are curves symmetric around $x=0$ and do not resemble the source signal histograms, except for the random wave which is Gaussian distributed. The $p_2$ distribution is proportional to the Gaussian distribution. The other distributions - $p_1, p_3, p_4$ - have heavier tails. The heavier tails ensure that the activation function can obtain robust estimators to outliers.

# %%
### 1.3 Implicit priors (continued)
# YOUR CODE HERE

### DEFINE PHIS ####
def phi_0(a):
    return -np.tanh(a)

def phi_1(a):
    return -a + np.tanh(a)

def phi_2(a):
    return - a**3

def phi_3(a):
    return - (6. * a) / (a**2 + 5.) 

#### DEFINE PRIORS ####
def prior_0(a):
    return 1. / np.cosh(a)

def prior_1(a):
    return np.exp(- a**2 * .5) * np.cosh(a)

def prior_2(a):
    return np.exp(- a**4 * .25)

def prior_3(a):
    return (a**2 + 5)**(-3)

def plot_funcs(funcs, titles, title=None, num_vals=1200):
    if funcs is None or titles is None:
        raise TypeError('Cannot plot None')
    
    if len(funcs) != len(titles):
        raise ValueError('funcs and titles must correspond.')
    
    # Values to plot
    vals = np.linspace(-10,10,num_vals) 
    fig = figure(figsize=(18,4))
    
    if title != None:
        fig.suptitle(title, fontsize=15)
    
    for i, (func, title) in enumerate(zip(funcs, titles)):
        res = func(vals)
        res = (res - np.min(res)) / (np.max(res) - np.min(res)) # normalize function
        plt.plot(vals, res)
        plt.legend(titles)
        plt.ylim(min(res), max(res) + 0.1)
        plt.xlim(min(vals), max(vals))

priors = [prior_0, prior_1, prior_2, prior_3]
phis = [phi_0, phi_1, phi_2, phi_3]

# Plot the normalized priors and activations
plot_funcs(priors, ['$p_0$', '$p_1$', '$p_2$', '$p_3$'], title='Priors')
plot_funcs(phis, ['$\phi_0$', '$\phi_1$', '$\phi_2$', '$\phi_3$'], title='Activation functions')

# %% [markdown]
# ### 1.4 Whitening (15 points)
# Some ICA algorithms can only learn from whitened data. Write a method `whiten(X)` that takes a $M \times T$ data matrix $\mathbf{X}$ (where $M$ is the dimensionality and $T$ the number of examples) and returns a whitened matrix. If you forgot what whitening is or how to compute it, various good sources are available online, such as http://courses.media.mit.edu/2010fall/mas622j/whiten.pdf

# %%
### 1.4 Whitening
def whiten(X):
    if X is None:
        raise TypeError('Cannot whiten None')
    
    # Zero mean normalization
    X -= np.mean(X, axis=1, keepdims=True)
    
    cov = np.cov(X)
    
    # Get eigenvectors, eigenvalues
    Lambda, Phi = np.linalg.eigh(cov)
    
    # Get diagonal eigen vectors
    Lambda = np.diag(Lambda)
    
    # Obtain \Lambda^{-1/2}
    Lambda = np.sqrt(np.linalg.inv(Lambda))
    
    # y = \Lambda \Phi^{T} X
    return np.dot(Lambda, np.dot(Phi.T, X))

Xw = whiten(X)

# %% [markdown]
# ### 1.5 Interpret results of whitening (10 points)
# Make scatter plots of the sources, measurements and whitened measurements. Each axis represents a source/measurement and each time-instance is plotted as a dot in this space. You can use the `np.scatter()` function. Describe what you see.
#
# Now compute the covariance matrix of the sources, the measurements and the whitened measurements. You can visualize a covariance matrix using this code:
# ```python
# # Dummy covariance matrix C;
# C = np.eye(5)
# ax = imshow(C, cmap='gray', interpolation='nearest')
# ```
#
# Are the signals independent after whitening?

# %%
### 1.5 Interpret results of whitening
# YOUR CODE HERE
matrices = [np.cov(S), np.cov(X), np.cov(Xw)]
titles = ['Sources', 'Measurements', 'Whitened Measurements']

fig = figure(figsize=(16,4))
fig.suptitle('Covariance matrices', fontsize=15)
for i, (cov_matrix, title) in enumerate(zip(matrices, titles)):
    ax = plt.subplot(1, len(titles), i + 1)
    plt.title(title)
    ax = imshow(cov_matrix, cmap='gray', interpolation='nearest')
plt.subplots_adjust(top=0.85)

def plot_scatter(data, titles, title=None):
    # TO-DO: - Layout and titles.
    fig = figure(figsize=(24,12))
    plot = 0
    
    if title != None:
        fig.suptitle(title, fontsize=15)
    
    for row in range(len(data)):
        row_title = titles[row]
        for col in range(len(data)):
            plot += 1
            ax = plt.subplot(len(data), len(data), plot)
            ax.set_title(titles[col])
            ax.set_ylabel(row_title)
            plt.scatter(data[row,:],data[col,:])
    plt.tight_layout()
    plt.subplots_adjust(top=0.90)

plot_scatter(S, ['saw_tooth', 'sine_wave', 'square_wave', 'triangle_wave', 'random_wave'] , title='Source signals')
plot_scatter(X, ['Mixture_1', 'Mixture_2', 'Mixture_3', 'Mixture_4', 'Mixture_5'], title='Mixture measurements')
plot_scatter(Xw, ['Whitened_Mix_1', 'Whitened_Mix_2', 'Whitened_Mix_3', 'Whitened_Mix_4', 'Whitened_Mix_5'], 
             title='Whitened mixture measurements') # Should be similar to X but decorrelated.

# %% [markdown]
# Whitening yields components that are _uncorrelated_ (as can be seen in the third set of scatter plots), but **not necessarily independent** ([1],[2]). The relatively strong linear relation of the mixtures is at least partially removed in the mixes after the whitening. However, this is not enough to confirm independence.
#
# - [1] http://www.jmlr.org/papers/volume4/cardoso03a/cardoso03a.pdf
# - [2] https://users.ics.aalto.fi/whyj/publications/thesis/thesis_node14.html

# %% [markdown]
# ### 1.6 Covariance (5 points)
# Explain what a covariant algorithm is.

# %% [markdown]
# An algorithm that gives the same results independent of the units in which quantities are measured ([3]).
#
# - [3] http://www.inference.phy.cam.ac.uk/mackay/ica.pdf

# %% [markdown]
# ### 1.7 Independent Component Analysis (25 points)
# Implement the covariant ICA algorithm as described in MacKay. Write a function `ICA(X, activation_function, learning_rate)`, that returns the demixing matrix $\mathbf{W}$. The input `activation_function` should accept a function such as `lambda a: -tanh(a)`. Update the gradient in batch mode, averaging the gradients over the whole dataset for each update. Try to make it efficient, i.e. use matrix operations instead of loops where possible (loops are slow in interpreted languages such as python and matlab, whereas matrix operations are internally computed using fast C code).

# %%
### 1.7 Independent Component Analysis
def ICA(X, activation_function, learning_rate=1e-3, epochs=100000):
    """
    Implements algorithm 34.4 from MacKay.
    """
    # Demixing matrix to be computed
    W = random_nonsingular_matrix(d=len(X))
    for i in range(epochs):
        # a = Wx
        a = np.dot(W,X)
        
        # z = \phi(a)
        z = activation_function(a)
        
        # a = W^{T} a
        x = np.dot(W.T, a)
        
        # dW ~ W + zx^{T}
        dW = W + np.dot(z,x.T) / X.shape[1]
        
        # Adjust weights
        W += learning_rate * dW
    
    return W

# %% [markdown]
# ### 1.8 Experiments  (5 points)
# Run ICA on the provided signals using each activation function $\phi_0, \ldots, \phi_3$. Plot the retreived signals for each choice of activation function.

# %%
# 1.8 Experiments
# YOUR CODE HERE
phi_titles = ['$\phi_0$', '$\phi_1$', '$\phi_2$', '$\phi_3$']
for _, (activ_func, activ_name) in enumerate(zip(phis, phi_titles)):
    # Obtain Demixing matrix
    W = ICA(Xw, activ_func)
    
    # Obtain retrieved signals
    Sig = np.dot(W, Xw)
    
    # Plot signal
    plot_signals(Sig, title='Reconstruction using ' + activ_name)

# %% [markdown]
# ### 1.9 Audio demixing (10 points)
# The 'cocktail party effect' refers to the ability humans have to attend to one speaker in a noisy room. We will now use ICA to solve a similar but somewhat idealized version of this problem. The code below loads 5 sound files and plots them.
#
# Use a random non-singular mixing matrix to mix the 5 sound files and save them to disk using the code below so you can listen to them. Plot histograms of the mixed audio and use your ICA implementation to de-mix these and reproduce the original source signals. As in the previous exercise, try each of the activation functions and report your results.
#
# Keep in mind that this problem is easier than the real cocktail party problem, because in real life there are often more sources than measurements (we have only two ears!), and the number of sources is unknown and variable. Also, mixing is not instantaneous in real life, because the sound from one source arrives at each ear at a different point in time. If you have time left, you can think of ways to deal with these issues.

# %%
import scipy.io.wavfile
# Save mixtures to disk, so you can listen to them in your audio player
def save_wav(data, out_file, rate):
    scaled = np.int16(data / np.max(np.abs(data)) * 32767)
    scipy.io.wavfile.write(out_file, rate, scaled)

# %%
# Load audio sources
source_files = ['beet.wav', 'beet9.wav', 'beet92.wav', 'mike.wav', 'street.wav']
wav_data = []
sample_rate = None
for f in source_files:
    sr, data = scipy.io.wavfile.read(f, mmap=False)
    if sample_rate is None:
        sample_rate = sr
    else:
        assert(sample_rate == sr)
    wav_data.append(data[:190000])  # cut off the last part so that all signals have same length

# Create source and measurement data
S_audio = np.c_[wav_data]
plot_signals(S_audio)

# %%
### 1.9 Audio demixing
# YOUR CODE HERE
W = random_nonsingular_matrix(d=S.shape[0])
X_audio = make_mixtures(S_audio, W)

plot_signals(X_audio, title='Mixed audio')
plot_histograms(X_audio, ['beet','beet9','beet92','mike','street'], title='Mixed audio')

# Save to disk
for i in range(X.shape[0]):
    save_wav(X[i, :], 'X_mix_' + str(i) + '.wav', sample_rate)
    
# First, whiten the mixed signals
Xw_audio = whiten(X_audio)

S_audio_rec = []
for _, (activ_func, title) in enumerate(zip(phis,phi_titles)): 
    # Obtain Demixing matrix
    W = ICA(Xw_audio, activ_func, learning_rate=1e-2, epochs=3000)
    
    # Obtain reconstructed audio sound
    S_audio_r = np.dot(W, Xw_audio)
    S_audio_rec.append(S_audio_r)    
        
    # Plot signal
    plot_signals(S_audio_r, title='Audio reconstructed with ' + title)

# Save reconstructed sounds only for phi_3
s3_audio_rec = S_audio_rec[-1]

for i in range(s3_audio_rec.shape[0]):
    save_wav(s3_audio_rec[i, :], 's3_audio_rec' + str(i) + '.wav', sample_rate)

# %% [markdown]
# We observe good reconstruction performance for the activation functions $\phi_0$ and $\phi_3$, which shows in the reconstructed signals bearing high resemblance to the source signals, which are a bit more complex than the the generated toy data.  Although the activation functions $\phi_1$ and $\phi_2$ performed well on the generated mixture measurements (see 1.8), they seem to produce poor results here.

# %% [markdown]
# ### 1.10 Excess Kurtosis (15 points)
# The (excess) kurtosis is a measure of 'peakedness' of a distribution. It is defined as
# $$
# \verb+Kurt+[X] = \frac{\mu_4}{\sigma^4} - 3 = \frac{\operatorname{E}[(X-{\mu})^4]}{(\operatorname{E}[(X-{\mu})^2])^2} - 3
# $$
# Here, $\mu_4$ is known as the fourth moment about the mean, and $\sigma$ is the standard deviation.
# The '-3' term is introduced so that a Gaussian random variable has 0 excess kurtosis.
# We will now try to understand the performance of the various activation functions by considering the kurtosis of the corresponding priors, and comparing those to the empirical kurtosis of our data.
#
# #### 1.10.1 (10 points)
# First, compute analytically the kurtosis of the four priors that you derived from the activation functions before. To do this, you will need the normalizing constant of the distribution, which you can either obtain analytically (good practice!), using computer algebra software (e.g. Sage) or by numerical integration (see scipy.integrate).

# %% [markdown]
# First, we obtain the normalizing constants of all 4 priors:
#
# $$p_0(a):$$
#
# $$\int \dfrac{1}{cosh(a)} \textit(da) = \arctan(\sinh(a))$$
# $$\int_{-\infty}^{\infty} \dfrac{1}{cosh(a)} \textit{da} = \lim_{a \rightarrow \infty}(arctan(sinh(a))) - \lim_{a\rightarrow -\infty}(arctan(sinh(a)) = \dfrac{\pi}{2} - (-\dfrac{\pi}{2}) = \pi$$
#
# $$p_1(a):$$
#
# $$\int_{-\infty}^{\infty} \exp(-\dfrac{a^{2}}{2}) \cdot cosh(a) \textit{da} = \sqrt{2e\pi}$$
#
# $$p_2(a):$$
# $$\int_{-\infty}^{\infty} \exp(-\dfrac{a^{4}}{4}) \textit{da} = \Gamma(\dfrac{1}{4}) \cdot 2^{-1/2}$$
#
# $$p_3(a):$$
# $$\int_{-\infty}^{\infty} (a^{2} + 5)^{-3} \textit{da} = \dfrac{3\pi}{8 \cdot \sqrt{5^{5}}} = \dfrac{3\pi}{200\sqrt{5}}$$
#
# ---
#
# We therefore have the following density functions:
#
# $$f_{0}(a) = \dfrac{1}{\pi} \cdot \dfrac{1}{cosh(a)} = \dfrac{1}{\pi\cosh(a)}$$
# $$f_{1}(a) = \dfrac{1}{\sqrt{2e\pi}} \cdot \exp(-\dfrac{a^{2}}{2}) \cdot cosh(a)$$
# $$f_{2}(a) = \dfrac{\sqrt{2}}{\Gamma(\dfrac{1}{4})} \cdot \exp(-\dfrac{a^{4}}{4})$$
# $$f_{3}(a) = \dfrac{200\sqrt{5}}{3\pi} \cdot (a^{2} + 5)^{-3}$$
#
# ---
#
# Before computing the Kurtosis, notice that all density functions are symmetric with respect to 0, using $-a^{2} = a^{2}$ and $cosh(-a) = cosh(a)$
#
# $$f_0(-a) = \dfrac{1}{\pi cosh(-a)} = \dfrac{1}{\pi cosh(a)} = f_0(a)$$
#
# $$f_1(-a) = \dfrac{\exp(-\dfrac{(-a)^{2}}{2})}{\sqrt{2e\pi}} \cdot cosh(-a) = \dfrac{\exp(-\dfrac{(a)^{2}}{2})}{\sqrt{2e\pi}} \cdot cosh(a) = f_1(a)$$
#
# $$f_2(-a) = \dfrac{\sqrt{2}}{\Gamma(\dfrac{1}{4})} \exp(-\dfrac{(-a)^{4}}{4}) = \dfrac{\sqrt{2}}{\Gamma(\dfrac{1}{4})} \exp(-\dfrac{(a)^{4}}{4}) = f_2(a)$$
#
# $$f_3(-a) = \dfrac{200\sqrt{5}}{3\pi} \cdot ((-a)^{2} + 5)^{-3} = \dfrac{200\sqrt{5}}{3\pi} \cdot ((a)^{2} + 5)^{-3}= f_3(a)$$
#
# ---
#
# Therefore when computing the Kurtosis we take $\mu = 0$:
#
# $$Kurt[X] = \dfrac{E[(x - \mu)^{4}]}{(E[(x - \mu)^{2}])^{2}} - 3 = \dfrac{E[x^{4}]}{(E[x^{2}])^{2}} - 3$$
#
# ---
#
#
# $$Kurt_{f_0}[X] = \dfrac{\int_{-\infty}^{\infty} \dfrac{x^{4}}{\pi \cosh(x)} \textit{dx}}{(\int_{-\infty}^{\infty} \dfrac{x^{2}}{\pi \cosh(x)} \textit{dx})^{2}} - 3= \dfrac{\dfrac{5\pi^{4}}{16}}{(\dfrac{\pi^2}{4})^{2}} - 3 = 5 - 3 = 2 $$
#
# $$Kurt_{f_1}[X] = \dfrac{\int_{-\infty}^{\infty} \dfrac{\exp(-\dfrac{(x)^{2}}{2})}{\sqrt{2e\pi}} \cdot cosh(x) \cdot x^{4} \textit{dx}}{\int_{-\infty}^{\infty} \dfrac{\exp(-\dfrac{(x)^{2}}{2})}{\sqrt{2e\pi}} \cdot cosh(x) \cdot x^{2} \textit{dx}} - 3 = \dfrac{10}{4} - 3 = -0.5$$
#
# $$Kurt_{f_2}[X] = \dfrac{\int_{-\infty}^{\infty} \dfrac{\sqrt{2}}{\Gamma(\dfrac{1}{4})} \cdot \exp(-\dfrac{x^{4}}{4}) \cdot x^{4} \textit{dx}}{(\int_{-\infty}^{\infty} \dfrac{\sqrt{2}}{\Gamma(\dfrac{1}{4})} \cdot \exp(-\dfrac{x^{4}}{4}) \cdot x^{2} \textit{dx})^{2}} - 3 \approx \dfrac{1}{0.45694} - 3  \approx - 0.8115288$$
#
# $$Kurt_{f_3}[X] = \dfrac{\int_{-\infty}^{\infty} \dfrac{200\sqrt{5}}{3\pi} \cdot (x^{2} + 5)^{-3} \cdot x^{4}\textit{dx}}{(\int_{-\infty}^{\infty} \dfrac{200\sqrt{5}}{3\pi} \cdot (x^{2} + 5)^{-3} \cdot x^{2}\textit{dx})^{2}} = \dfrac{25 * 9}{25} - 3 = 6$$

# %% [markdown]
# #### 1.10.2 (5 points)
# Now use the `scipy.stats.kurtosis` function, with the `fisher` option set to `True`, to compute the empirical kurtosis of the dummy signals and the real audio signals.
#
# Can you use this data to explain the performance of the various activation functions on the synthetic and real data?

# %%
### 1.10.2 Excess Kurtosis
# YOUR CODE HERE
from scipy.stats import kurtosis

def display_kurtosis(data, pre=None):
    if data is None:
        raise TypeError('Cannot compute kurtosis for None')
        
    if pre:
        print(pre)
        
    kurt = np.sort(np.array(kurtosis(data, axis=1, fisher=True)))
    print(kurt)
    return kurt

display_kurtosis(S, pre='Kurtosis of dummy data ' + str(i+1))
print('-----------------------------------')
display_kurtosis(X_audio, pre='Kurtosis of observed audio:')
print('-----------------------------------')
S_kurt = display_kurtosis(S_audio, pre='Kurtosis of source audio:')

print 


for (reconstr_audio, phi_used) in zip(S_audio_rec, phi_titles):
    print('-----------------------------------')
    reconstr_kurt = display_kurtosis(reconstr_audio, pre=('Kurtosis of reconstructed audio using ' + phi_used))
    print "L2-distance of " + phi_used  + " kurtosis with source audio kurtosis:"
    print np.linalg.norm(S_kurt-reconstr_kurt)
# Out:
# Kurtosis of dummy data 1
# [-1.84019701 -1.48287113 -1.2000384  -1.19640244 -0.1746481 ]
# -----------------------------------
# Kurtosis of observed audio:
# [ 0.44422264  0.56532676  0.60945191  0.64028379  1.06344358]
# -----------------------------------
# Kurtosis of source audio:
# [ 0.53887581  1.79431517  1.93609295  2.06885064  5.05191721]
#
# -----------------------------------
# Kurtosis of reconstructed audio using $\phi_0$
# [ 0.53895263  1.79517963  1.93492092  2.07369255  5.05330059]
# L2-distance of $\phi_0$ kurtosis with source audio kurtosis:
# 0.00524258642711
# -----------------------------------
# Kurtosis of reconstructed audio using $\phi_1$
# [ 0.22855226  0.28644721  0.46388454  0.51419945  0.6327399 ]
# L2-distance of $\phi_1$ kurtosis with source audio kurtosis:
# 5.14620563628
# -----------------------------------
# Kurtosis of reconstructed audio using $\phi_2$
# [ 0.30749828  0.35806193  0.38914747  0.42803463  0.44456333]
# ...

# %% [markdown]
# We compare the kurtosis values of the source audio and the reconstructed audio above. To obtain a scalar similarity measure, we sort the kurtosis values (since the signals are unordered after demixing) and compute the $L^2$-distance from the sorted source audio kurtosis. The $L^2$-distances confirm our visual results that $\phi_0$ and $\phi_3$ perform better than $\phi_1$ and $\phi_2$. Surprisingly, $\phi_0$ seems to outperform even $\phi_3$ by a considerable margin with this measure.
# Concluding, our results support the notion that kurtosis is a good similary measure. However, more elaborate comparison work needs to be done to verify the practical value of this measure.
